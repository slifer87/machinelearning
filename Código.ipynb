# %%
# Analisar o dataset
# Análise dos tipos de dados do dataset, com a quantidade de registros não nulos, quantidade totais de registros por coluna/feature.

import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm


#sales=sns.load_dataset("sales")
#sales.info()

wine =sns.load_dataset("wine")
#print("Listagem de dados do Dataset")
#wine.info()

# Aqui podemos já detectar uma feature ("region_2region_2") que possui muitos registros nulos, portanto, um canditado para ser 
# avaliado e talvez excluído do dataset.
#Vemos aqui também que a maioria das demais colunas estão com todos os registros não-nulos, ou bem próximo disso, havendo então 
#apenas a necessidade de aplicar alguma lógica para preencher os campos nulos, podendo ser pela média, mediana ou outras alternativas. 


print("Listando somatório de registros nulos por feature/coluna")

#soma_nulos = pd.read_csv('wine.csv')
#print(wine.isna().sum())
#wine.shape


#Como podemos ver temos então 1 columa "region_2" com mais de 50% dos dados nulos, temos a feature "designation" com mais de 45mil do 150mil
#registros nulos. Há aqui a necessidade de identificar se essa feature é importante para a análise, caso seja, pensar em uma maneira de 
#substituir os dados nulos. Caso não seja, deverá ser excluída.
#Colunas a serem normalizadas: "country", "price", "province" e "region_1".

#Retirar colunas inúteis, como é a coluna de "Unnamed".
#wine.loc('country','points','price','province','region_1','variety','winery')

wine1 = wine[["country","points",'price','province','region_1','variety','winery']].head(100)
wine1
#wine.head(5)



#verificar duplicadas
#duplica=wine.append(wine)
#wine.info()
#duplica.info()
#duplica.drop_duplicates()
#duplica.info()




#sns.displot(data=wine,             x="cut", y="price", col="color");
#duplica=diamonds.append(diamonds)
#wine.head()


# a fazer ainda
#sns.relplot(data=wine, x="country", y="points", col="price", hue="variety" ,style="variety")
# Out:
# Listando somatório de registros nulos por feature/coluna
#    country  points  price          province           region_1  \
# 0       US      96  235.0        California        Napa Valley
# 1    Spain      96  110.0    Northern Spain               Toro
# 2       US      96   90.0        California     Knights Valley
# 3       US      96   65.0            Oregon  Willamette Valley
# 4   France      95   66.0          Provence             Bandol
# ..     ...     ...    ...               ...                ...
# 95  France      86   14.0  Southwest France             Cahors
# 96      US      86   18.0        California         California
# 97      US      86   36.0        California      Sonoma Valley
# 98  France      86   15.0  Southwest France              Buzet
# 99  France      86   10.0  Southwest France  Côtes de Gascogne
#
#                  variety                   winery
# 0     Cabernet Sauvignon                    Heitz
# 1          Tinta de Toro  Bodega Carmen Rodríguez
# 2        Sauvignon Blanc                 Macauley
# 3             Pinot Noir                    Ponzi
# 4     Provence red blend     Domaine de la Bégude
# ..                   ...                      ...
# 95         Malbec-Merlot                    Rigal
# 96            Chardonnay          The Naked Grape
# 97    Cabernet Sauvignon                 Tin Barn
# 98         Merlot-Malbec        Georges Vigouroux
# 99  Ugni Blanc-Colombard        Georges Vigouroux
#
# [100 rows x 7 columns]

# %%
import numpy as np
import seaborn as sns
#from scipy import stats
from scipy.stats import norm
import pandas as pd

diamonds =sns.load_dataset("diamonds")
diamonds.columns
#diamonds.str.upper() 
#diamonds.head() 
#diamonds.columns=[col.upper() for col in diamonds]
#diamonds.columns

diamonds.columns=[col.lower() for col in diamonds]
diamonds.columns

#retorna valores nulos
diamonds.isnull() #não é viavel
diamonds.isnull().sum()
diamonds
diamonds.shape
diamonds
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 352   0.90     Fair     I     SI1   67.3   59.0   2804  5.93  5.84  3.96
# 353   0.74  Premium     F     VS2   61.7   58.0   2805  5.85  5.78  3.59
# 354   0.74  Premium     F     VS2   61.9   56.0   2805  5.80  5.77  3.58
# 355   0.73    Ideal     E     SI2   61.8   58.0   2805  5.77  5.81  3.58
# 356   0.57     Fair     E    VVS1   58.7   66.0   2805  5.34  5.43  3.16
#
# [357 rows x 10 columns]

# %%
import numpy as np
import seaborn as sns
#from scipy import stats
from scipy.stats import norm
import pandas as pd


#correlação entre colunas / identificar correlacionamentos entre as features 
#quanto mais perto de 1 (+ ou -) maior é a indicação de correlacionamento
diamonds =sns.load_dataset("diamonds")
diamonds.corr()

# %%
import numpy as np
import seaborn as sns
#from scipy import stats
from scipy.stats import norm
import pandas as pd

#fazer split de x até y e apresentar apenas esses valores
diamonds =sns.load_dataset("diamonds")
diamonds.iloc[0:9]
#diamonds.set_index('carat').head(8)


import numpy as np
import seaborn as sns
#from scipy import stats
from scipy.stats import norm
import pandas as pd

#fazer split de x até y e apresentar apenas esses valores
diamonds =sns.load_dataset("diamonds")
diamonds.set_index('cut')
#diamonds.loc('Ideal':'Fair')


import numpy as np
import seaborn as sns
#from scipy import stats
from scipy.stats import norm
import pandas as pd

#fazer split de x até y e apresentar apenas esses valores
diamonds =sns.load_dataset("diamonds")

diamonds1 = diamonds[["x","color","clarity", "price"]].head(100)
#diamonds1 = diamonds['clarity':'price']
diamonds1[(diamonds1['clarity']=='VS1') & (diamonds1['color']=='E')]
#diamonds1[(diamonds1['clarity']=='VS1') | (diamonds1['clarity']=='VVS1')]
